# %%
# Kristen Aalbue
# Lab 3: Diff Eq Solver
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def euler_newton(force, times, x0, v0, m,dt):
    # create arrays for x and v
    x = []
    v = []
    # store the initial conditions in the first elements
    x.append(x0)
    v.append(v0)
    
    for i in range(nsteps-1):
        a = force(times[i], x[i], v[i]) / m
        v.append(v[i] + (a * dt))
        x.append(x[i] + (v[i] * dt))
    return x, v
nsteps=100000
times,dt = np.linspace(0, 100, nsteps, retstep=True)

# %%
m = 10

def gravity(t, x, v):
    g = 9.8
    F = (-m) * g
    return F
    x = 10
    v = 0
print(gravity(10, 10, 0))
x0=10
v0=0
x,v=euler_newton(gravity, times, x0, v0, m,dt)
# Out:
# -98.0

# %%
analyx = (x0 + v0*times - ((0.5*9.8)*times**2))

# %%
plt.plot(times,x)
plt.plot(times,analyx,ls="dotted")
plt.grid
plt.title("Analytical and Numerical Solutions of Position and Time")
plt.xlabel("Time (s)")
plt.ylabel("Position (m)")
plt.tight_layout()
plt.show()

# %%
analyv = (v0 - 9.8*times)

# %%
plt.plot(times,v)
plt.plot(times,analyv,ls="dotted")
plt.grid
plt.title("Analytical and Numerical Solutions of Velocity and Time")
plt.xlabel("Time (s)")
plt.ylabel("Velocity (m/s)")
plt.tight_layout()
plt.show()

# %%
# Part 2 Questions:
#1. Yes, the motion matches the calculated results we derived last year in Gen Physics 1.
#2. Yes.
#3. An increase in number of time steps makes a more accurate graph that fits with the projectile motion equation.
#4. The object hits the ground at about 10 seconds.

# %%
def spring(t,x,v):
    return (-1)*k*x

m = 1
k = 1
x0 = 1
v0 = 0

euler = euler_newton(spring,times, x0, v0, m,dt)

def xt(t):
    return np.cos(t)
def vt(t):
    return (-1)*np.sin(t)

# %%
plt.plot(times, euler[0])
plt.plot(times,xt(times),ls="dotted")
plt.grid
plt.title("Simple Oscillator Position")
plt.xlabel("Time (s)")
plt.ylabel("Position (m)")
plt.tight_layout()
plt.show()

# %%
plt.plot(times, euler[1])
plt.plot(times,vt(times),ls="dotted")
plt.grid
plt.title("Simple Oscillator Velocity")
plt.xlabel("Time (s)")
plt.ylabel("Velocity (m/s)")
plt.tight_layout()
plt.show()

# %%
# Part 3 Questions:
#1. Yes it does.
#2. For 10 seconds, the calculated position follows the analytical solution exactly.
#3. Smaller changes in time cause fewer oscillations.
#4. I know this code is working correctly because there is a clear equilibrium and the analytical solution matches the numerical one.
